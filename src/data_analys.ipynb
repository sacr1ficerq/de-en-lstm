# %%
from dataset import TranslationDataset, Vocab
from submission import get_bleu

# %% [markdown]
# ## min_freq

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from config import filenames

# %%
from dataset2 import Vocab
vocab_src = Vocab(filenames['train_src'], min_freq=1, use_sub=False, use_bpe=True)
vocab_trg = Vocab(filenames['train_trg'], min_freq=5, use_sub=False)

# %%
cnt = vocab_src.token_counter
cnt
# Out:
# Counter({'▁,': 268564,
#          '▁.': 199977,
#          '▁und': 96684,
#          '▁die': 88951,
#          '▁sie': 59858,
#          '▁das': 57778,
#          '▁ich': 56767,
#          '▁der': 55960,
#          '▁ist': 50560,
#          '▁wir': 48399,
#          '▁es': 47560,
#          '▁in': 45496,
#          '▁zu': 42811,
#          '▁ein': 30226,
#          '▁"': 27553,
#          '▁nicht': 27024,
#          '▁eine': 26998,
#          '▁von': 26883,
#          '▁dass': 26637,
#          '▁den': 22426,
#          '▁mit': 22257,
#          '▁wie': 20515,
#          '▁auf': 20388,
#          '▁:': 17811,
#          '▁sich': 17788,
#          '▁sind': 17334,
#          '▁aber': 17104,
#          '▁man': 16891,
#          '-': 16767,
#          '▁haben': 16634,
#          '▁für': 16621,
#          '▁?': 16433,
#          '▁wenn': 16394,
#          '▁was': 15898,
#          '▁als': 15170,
#          '▁an': 15106,
#          '▁so': 14504,
#          '▁diese': 14248,
#          '▁war': 13948,
#          '▁um': 13554,
#          '▁er': 13117,
#          '▁im': 12692,
#          '▁dem': 11618,
#          '▁also': 11180,
#          '▁einen': 10790,
#          '▁uns': 10617,
#          '▁aus': 10427,
#          '▁können': 10285,
#          '▁oder': 10205,
#          '▁werden': 9822,
#          '▁hier': 9816,
#          '▁hat': 9403,
#          '▁über': 9312,
#          '▁': 9132,
#          '▁auch': 8928,
#          '▁des': 8798,
#          '▁einer': 8676,
#          '▁kann': 8458,
#          '▁einem': 8295,
#          '▁nur': 8162,
#          '▁dann': 8120,
#          '▁sehr': 8090,
#          '▁wird': 7902,
#          '▁menschen': 7461,
#          '▁mich': 7305,
#          '▁ihnen': 7282,
#          '▁gibt': 7262,
#          '▁–': 7157,
#          '▁nach': 6739,
#          '▁--': 6736,
#          '▁sein': 6648,
#          '▁sehen': 6647,
#          '▁vor': 6576,
#          '▁dieser': 6553,
#          '▁etwas': 6545,
#          '▁noch': 6466,
#          '▁habe': 6199,
#          '▁mir': 6093,
#          '▁bei': 5764,
#          's': 5665,
#          '▁mehr': 5642,
#          '▁alle': 5455,
#          '▁welt': 5416,
#          '▁ihre': 5203,
#          '▁meine': 5136,
#          '▁zum': 5032,
#          '▁weil': 4974,
#          '▁durch': 4902,
#          '▁wurde': 4861,
#          '▁leben': 4818,
#          '▁da': 4767,
#          '▁dieses': 4758,
#          '▁machen': 4736,
#          '▁wirklich': 4633,
#          '▁nun': 4570,
#          '▁immer': 4481,
#          '▁dies': 4426,
#          '▁unsere': 4329,
#          '▁ihr': 4324,
#          '▁am': 4305,
#          '▁jetzt': 4234,
#          '▁tun': 4229,
#          '▁wissen': 4196,
#          '▁viel': 4007,
#          '▁hatte': 3994,
#          '▁viele': 3991,
#          '▁-': 3990,
#          '▁keine': 3976,
#          '▁zeit': 3954,
#          '▁leute': 3775,
#          '▁zwei': 3692,
#          '▁denn': 3652,
#          '▁diesem': 3625,
#          '▁du': 3609,
#          '▁sagen': 3594,
#          '▁eines': 3587,
#          '▁waren': 3582,
#          '▁müssen': 3581,
#          '▁dinge': 3565,
#          '▁diesen': 3564,
#          '▁einfach': 3542,
#          '▁sagte': 3527,
#          '.': 3519,
#          '▁alles': 3491,
#          '▁selbst': 3431,
#          '▁jahren': 3428,
#          '▁andere': 3414,
#          '▁bin': 3308,
#          '▁wo': 3287,
#          '▁art': 3253,
#          '▁damit': 3243,
#          '▁anderen': 3221,
#          '▁würde': 3155,
#          '▁mein': 3152,
#          '▁vielleicht': 3123,
#          '▁zur': 3082,
#          '▁bis': 3024,
#          '▁gut': 2980,
#          '▁geht': 2889,
#          '▁mal': 2869,
#          '▁jahre': 2815,
#          '▁muss': 2710,
#          '▁wieder': 2703,
#          '▁heute': 2694,
#          '▁schon': 2649,
#          '▁warum': 2602,
#          '▁all': 2535,
#          '▁einige': 2523,
#          'es': 2512,
#          '▁möchte': 2506,
#          '▁ja': 2497,
#          '▁kinder': 2474,
#          '▁tatsächlich': 2418,
#          '▁macht': 2404,
#          '▁davon': 2384,
#          '▁drei': 2384,
#          '▁ganz': 2375,
#          '▁genau': 2313,
#          '▁dort': 2310,
#          'er': 2308,
#          '▁ob': 2299,
#          '▁denken': 2252,
#          '▁hatten': 2237,
#          '▁geschichte': 2226,
#          '▁ab': 2193,
#          '▁paar': 2166,
#          '▁;': 2157,
#          '▁könnte': 2153,
#          '▁ihn': 2149,
#          '▁unter': 2140,
#          '▁zurück': 2136,
#          '▁gehen': 2128,
#          '▁darüber': 2122,
#          '▁jahr': 2111,
#          'te': 2108,
#          '▁wollen': 2106,
#          "▁'": 2066,
#          '▁meiner': 2063,
#          'e': 2045,
#          '▁wurden': 2045,
#          '▁weg': 2040,
#          '▁werde': 2038,
#          '▁seine': 2017,
#          '▁ihren': 1992,
#          '▁vielen': 1991,
#          '▁zusammen': 1986,
#          '▁lassen': 1979,
#          'd': 1961,
#          'de': 1961,
#          '▁beispiel': 1942,
#          '▁teil': 1934,
#          '▁sondern': 1931,
#          '▁weiter': 1925,
#          '▁gab': 1913,
#          'ten': 1905,
#          '▁jeder': 1896,
#          '▁dazu': 1895,
#          '▁doch': 1889,
#          '▁problem': 1882,
#          '!': 1872,
#          '▁unserer': 1860,
#          '▁wäre': 1859,
#          'en': 1853,
#          '▁kein': 1847,
#          '▁während': 1844,
#          '▁sogar': 1823,
#          '▁vom': 1819,
#          '▁natürlich': 1818,
#          '▁neue': 1807,
#          '▁kommen': 1802,
#          '▁frage': 1801,
#          '▁denke': 1797,
#          '▁finden': 1782,
#          '▁unser': 1776,
#          '▁einmal': 1775,
#          '▁zwischen': 1766,
#          '▁weiß': 1741,
#          '▁glaube': 1735,
#          '▁nichts': 1734,
#          '▁geben': 1723,
#          '▁gemacht': 1721,
#          '▁ohne': 1715,
#          '▁ihrer': 1707,
#          '▁tag': 1706,
#          '▁denen': 1699,
#          '▁dafür': 1696,
#          '▁gerade': 1694,
#          '▁kommt': 1692,
#          '▁wasser': 1685,
#          '▁würden': 1659,
#          'in': 1654,
#          'den': 1629,
#          '▁frauen': 1629,
#          '▁will': 1623,
#          '▁zeigen': 1619,
#          '▁sieht': 1602,
#          '▁arbeit': 1599,
#          '▁verstehen': 1593,
#          '▁passiert': 1585,
#          '▁nie': 1564,
#          '▁ersten': 1557,
#          '▁erste': 1557,
#          '▁prozent': 1554,
#          '▁konnte': 1551,
#          '▁stellen': 1540,
#          '▁ganze': 1534,
#          '▁s': 1531,
#          '▁etwa': 1528,
#          '▁daran': 1527,
#          '▁land': 1524,
#          '▁millionen': 1521,
#          '▁nehmen': 1495,
#          '▁sollte': 1490,
#          '▁fragen': 1483,
#          '▁große': 1480,
#          '▁dabei': 1466,
#          '▁arbeiten': 1460,
#          '▁sollten': 1459,
#          'liche': 1457,
#          '▁letzten': 1448,
#          'st': 1447,
#          '▁idee': 1440,
#          '▁könnten': 1439,
#          'lichen': 1435,
#          '▁bild': 1427,
#          '▁sprechen': 1410,
#          '▁meinen': 1403,
#          '▁daten': 1394,
#          '▁ziemlich': 1394,
#          '▁wollte': 1391,
#          'ern': 1387,
#          '▁meisten': 1377,
#          '▁bekommen': 1363,
#          '▁geld': 1362,
#          '▁meinem': 1361,
#          '▁darauf': 1335,
#          '▁kam': 1334,
#          '▁wichtig': 1333,
#          '▁sagt': 1330,
#          '▁besser': 1327,
#          '▁dank': 1323,
#          'ung': 1322,
#          '▁ging': 1321,
#          '▁gehirn': 1318,
#          '▁welche': 1318,
#          '▁eigentlich': 1311,
#          'o': 1289,
#          '▁grund': 1278,
#          't': 1261,
#          'a': 1261,
#          '▁vier': 1260,
#          '▁weniger': 1253,
#          '▁danke': 1252,
#          '▁kleinen': 1251,
#          '▁ende': 1250,
#          '▁glauben': 1245,
#          '▁heraus': 1226,
#          '▁technologie': 1222,
#          '▁bedeutet': 1213,
#          '▁10': 1209,
#          '▁sache': 1206,
#          '▁lernen': 1204,
#          '▁dollar': 1199,
#          '▁wissenschaft': 1197,
#          '▁jemand': 1195,
#          '▁unseren': 1189,
#          '▁ihm': 1185,
#          '▁mann': 1184,
#          '▁kleine': 1181,
#          '▁bringen': 1172,
#          '▁raum': 1171,
#          '▁dachte': 1170,
#          '▁großen': 1168,
#          '▁wer': 1165,
#          '▁gesehen': 1163,
#          'y': 1162,
#          '▁gegen': 1158,
#          '▁ins': 1157,
#          'sten': 1156,
#          '▁ganzen': 1156,
#          '▁wahrscheinlich': 1152,
#          '▁ihrem': 1151,
#          'ungen': 1150,
#          '▁pro': 1135,
#          '▁brauchen': 1135,
#          'm': 1133,
#          '▁seit': 1131,
#          '▁versuchen': 1130,
#          '▁weise': 1130,
#          '„': 1128,
#          '▁seite': 1127,
#          '▁jedes': 1127,
#          '▁computer': 1124,
#          'b': 1108,
#          '▁jeden': 1106,
#          '▁hin': 1105,
#          '▁energie': 1105,
#          '▁nein': 1105,
#          '▁beim': 1103,
#          '▁...': 1085,
#          '▁nutzen': 1082,
#          '▁person': 1080,
#          '▁frau': 1076,
#          '▁später': 1073,
#          '▁keinen': 1059,
#          '▁menge': 1059,
#          '▁indem': 1056,
#          '▁fast': 1055,
#          'k': 1052,
#          '▁hoch': 1050,
#          '▁gesagt': 1042,
#          '▁fünf': 1042,
#          '▁hätte': 1033,
#          'ter': 1022,
#          '▁sicher': 1022,
#          'an': 1021,
#          'em': 1016,
#          'ste': 1011,
#          '▁zukunft': 1007,
#          '▁gute': 1005,
#          '▁ort': 1004,
#          '▁jede': 1003,
#          'i': 1001,
#          '▁kind': 1000,
#          '%': 998,
#          '“': 998,
#          '▁heißt': 989,
#          '▁funktioniert': 989,
#          '▁20': 989,
#          '▁schaffen': 987,
#          '▁konnten': 985,
#          '▁eigenen': 983,
#          '▁lebens': 982,
#          '▁schnell': 979,
#          'lich': 966,
#          '▁wenig': 966,
#          '▁unterschied': 965,
#          '▁körper': 961,
#          '▁oft': 958,
#          '▁moment': 957,
#          '▁richtig': 952,
#          '▁erst': 952,
#          '▁stadt': 952,
#          '▁natur': 933,
#          '▁schauen': 931,
#          '▁b': 930,
#          '▁erde': 929,
#          'ische': 927,
#          '▁erzählen': 926,
#          '▁allen': 926,
#          '▁je': 923,
#          '▁seiner': 921,
#          '▁ungefähr': 918,
#          '▁probleme': 916,
#          '▁fall': 915,
#          '▁möglich': 915,
#          'f': 913,
#          '▁un': 913,
#          '▁essen': 913,
#          '▁spielen': 911,
#          '▁mutter': 911,
#          '▁helfen': 911,
#          '▁hand': 902,
#          '▁anders': 902,
#          'p': 901,
#          '▁licht': 899,
#          '▁sah': 896,
#          'h': 894,
#          '▁lange': 890,
#          '▁system': 889,
#          '▁nächsten': 889,
#          '▁neuen': 888,
#          '▁genug': 880,
#          '▁zeigt': 880,
#          '▁lang': 878,
#          '▁begann': 876,
#          '▁unserem': 875,
#          '▁darum': 873,
#          '▁liebe': 871,
#          '▁sei': 865,
#          'g': 862,
#          'al': 856,
#          '▁manchmal': 853,
#          '▁bauen': 852,
#          '▁bevor': 847,
#          '▁form': 846,
#          '▁bisschen': 845,
#          'le': 844,
#          'ischen': 843,
#          'ungs': 841,
#          '▁überall': 840,
#          '▁ideen': 837,
#          '▁euch': 836,
#          '▁usa': 834,
#          '▁okay': 834,
#          'ieren': 830,
#          'der': 829,
#          '▁buch': 828,
#          'w': 828,
#          '▁liegt': 827,
#          '▁reden': 819,
#          '▁weit': 817,
#          '▁internet': 817,
#          'be': 815,
#          '▁deshalb': 811,
#          '▁informationen': 809,
#          'on': 807,
#          '▁herum': 806,
#          '▁kennen': 805,
#          '▁gleich': 804,
#          '▁planeten': 803,
#          '▁nennen': 803,
#          '▁verändern': 803,
#          '▁seinen': 801,
#          'c': 801,
#          'isch': 798,
#          '▁augen': 797,
#          'n': 796,
#          '▁gehört': 795,
#          '▁leuten': 794,
#          '▁gar': 793,
#          '▁stehen': 791,
#          '▁schule': 789,
#          '▁gesellschaft': 785,
#          '▁musik': 782,
#          '▁z': 781,
#          '▁sagten': 780,
#          '▁hören': 778,
#          '▁afrika': 778,
#          'u': 776,
#          '▁anderes': 775,
#          '▁milliarden': 773,
#          '▁recht': 772,
#          '▁antwort': 769,
#          '▁klar': 768,
#          '▁oben': 767,
#          '▁30': 767,
#          '▁punkt': 765,
#          '▁besonders': 764,
#          '▁sechs': 761,
#          '▁50': 760,
#          '▁tat': 758,
#          '▁arten': 756,
#          '▁ver': 756,
#          'ig': 755,
#          '▁unternehmen': 754,
#          '▁männer': 751,
#          '▁musste': 749,
#          '▁bereits': 748,
#          '▁halten': 742,
#          '▁entwickelt': 742,
#          'tes': 742,
#          '▁darin': 739,
#          '▁erreichen': 735,
#          '▁projekt': 734,
#          '▁benutzen': 733,
#          '▁verschiedene': 733,
#          '▁wirtschaft': 733,
#          '▁hätten': 732,
#          '▁dich': 730,
#          '▁ok': 730,
#          '▁new': 729,
#          '▁steht': 725,
#          'iert': 725,
#          '▁namens': 720,
#          '▁gerne': 719,
#          'el': 718,
#          '▁machte': 718,
#          '▁seinem': 718,
#          '▁erkennen': 716,
#          '▁minuten': 716,
#          '▁mädchen': 716,
#          '▁her': 715,
#          '▁kunst': 713,
#          '▁kopf': 712,
#          '▁teilen': 708,
#          '▁ted': 707,
#          '▁haus': 703,
#          '▁100': 703,
#          '▁e': 701,
#          '▁schwer': 700,
#          '▁neu': 699,
#          '▁design': 697,
#          '▁glück': 695,
#          'z': 694,
#          'is': 693,
#          '▁innerhalb': 691,
#          '▁groß': 690,
#          '▁gesundheit': 689,
#          '▁familie': 688,
#          '▁r': 688,
#          '▁a': 688,
#          '▁geschichten': 686,
#          '▁irgendwie': 685,
#          'ge': 684,
#          '▁bilder': 681,
#          'sch': 681,
#          '▁soll': 681,
#          '▁ge': 675,
#          '▁sprache': 675,
#          '▁kurz': 674,
#          '▁niemand': 671,
#          '▁einzige': 670,
#          '▁jedem': 669,
#          '▁gruppe': 669,
#          'ing': 669,
#          '▁film': 668,
#          '▁verhalten': 667,
#          '▁ca': 667,
#          '▁angst': 666,
#          '▁gefühl': 665,
#          'or': 665,
#          '▁indien': 665,
#          '▁wegen': 664,
#          '▁spiel': 664,
#          'os': 663,
#          '▁vorstellen': 660,
#          '▁braucht': 658,
#          '▁auto': 656,
#          '▁daher': 656,
#          '▁fest': 655,
#          '▁gott': 654,
#          '▁entwickeln': 653,
#          'igen': 651,
#          '▁gleiche': 651,
#          'as': 650,
#          'at': 650,
#          '▁obwohl': 649,
#          'bar': 649,
#          '▁bitte': 647,
#          '▁oh': 646,
#          '▁stunden': 645,
#          '▁verschiedenen': 644,
#          '▁besten': 640,
#          '▁möglichkeit': 638,
#          '▁luft': 638,
#          '▁bewegen': 637,
#          '▁treffen': 635,
#          '▁g': 634,
#          '▁wort': 634,
#          '▁erhalten': 634,
#          '▁aller': 632,
#          '▁vater': 631,
#          '▁los': 630,
#          '▁einigen': 629,
#          '▁nämlich': 629,
#          '▁c': 629,
#          '▁m': 627,
#          'l': 627,
#          '▁unglaublich': 625,
#          '▁ändern': 625,
#          '▁beginnen': 624,
#          'ie': 624,
#          '▁wollten': 624,
#          '▁sachen': 623,
#          '▁damals': 622,
#          'us': 620,
#          '▁sinn': 618,
#          '▁wohl': 617,
#          '▁alt': 615,
#          '▁eher': 615,
#          '▁patienten': 613,
#          '▁sage': 611,
#          '▁hause': 611,
#          '▁eltern': 611,
#          '▁eins': 610,
#          '▁beiden': 609,
#          '▁t': 607,
#          '▁p': 605,
#          '▁verwenden': 605,
#          '▁gebäude': 604,
#          '▁regierung': 602,
#          '▁kindern': 599,
#          'ar': 597,
#          '▁verändert': 595,
#          '[': 594,
#          '▁ziel': 594,
#          ']': 592,
#          '▁mag': 591,
#          '▁überhaupt': 591,
#          '▁roboter': 589,
#          '▁tut': 588,
#          '▁getan': 588,
#          '▁15': 588,
#          '▁dir': 586,
#          '▁hinter': 585,
#          '▁menschlichen': 581,
#          '▁länder': 579,
#          '▁l': 579,
#          '▁schreiben': 578,
#          '▁zwar': 577,
#          '▁fand': 576,
#          '▁video': 575,
#          '▁stück': 573,
#          'ver': 572,
#          '▁universum': 572,
#          '▁sch': 571,
#          '▁versucht': 571,
#          '▁gleichen': 571,
#          '▁k': 570,
#          '▁allem': 567,
#          'ige': 566,
#          '▁wert': 564,
#          '▁nächste': 562,
#          '▁solche': 560,
#          '▁lage': 560,
#          'r': 559,
#          '▁china': 558,
#          '▁f': 557,
#          '▁schön': 549,
#          '▁führen': 549,
#          '▁jedoch': 548,
#          '▁erfahrung': 547,
#          '▁nachdem': 546,
#          '▁junge': 545,
#          '▁entwicklung': 543,
#          '▁mussten': 543,
#          '▁betrachten': 542,
#          '▁weitere': 542,
#          '▁kultur': 540,
#          '▁fühlen': 540,
#          '▁anfang': 539,
#          '▁kamen': 539,
#          'ierte': 537,
#          '▁tiere': 536,
#          '▁meines': 536,
#          '▁letzte': 535,
#          'licher': 535,
#          '▁n': 534,
#          '▁dingen': 534,
#          '▁unten': 532,
#          '▁genauso': 531,
#          '▁schließlich': 530,
#          '▁freunde': 530,
#          '▁umwelt': 528,
#          '▁krebs': 528,
#          'des': 526,
#          'ischer': 526,
#          '▁publikum': 526,
#          'eln': 525,
#          '▁erinnern': 524,
#          '▁danach': 524,
#          '▁lehrer': 523,
#          '▁sieben': 521,
#          '▁falsch': 521,
#          '▁2': 519,
#          '▁bringt': 519,
#          '▁lesen': 518,
#          '▁völlig': 517,
#          '▁wusste': 517,
#          '▁eigene': 515,
#          '▁lässt': 515,
#          'ierten': 515,
#          '▁3': 514,
#          '▁gedanken': 514,
#          '▁grunde': 513,
#          'ik': 512,
#          '▁wären': 512,
#          '▁wahr': 511,
#          '▁worden': 510,
#          'ur': 509,
#          '▁h': 508,
#          '▁thema': 508,
#          '▁menschliche': 507,
#          '▁interessant': 504,
#          '▁w': 504,
#          '▁hilfe': 503,
#          '▁direkt': 503,
#          '▁möglichkeiten': 503,
#          '▁stellt': 502,
#          '▁sollen': 502,
#          '▁deren': 501,
#          '▁jungen': 500,
#          '▁wochen': 499,
#          'um': 499,
#          'alen': 497,
#          '▁40': 497,
#          'ien': 497,
#          'heit': 497,
#          '▁boden': 496,
#          '▁zweite': 496,
#          '▁lösen': 495,
#          '▁be': 495,
#          '▁suchen': 494,
#          '▁staaten': 494,
#          '▁welches': 494,
#          '▁plötzlich': 494,
#          're': 493,
#          'se': 493,
#          '▁york': 492,
#          'gen': 491,
#          '▁tages': 491,
#          '▁fragte': 491,
#          '▁manche': 490,
#          '▁zuerst': 490,
#          'ere': 489,
#          '▁bleiben': 489,
#          '▁mensch': 487,
#          '▁st': 487,
#          '▁dessen': 487,
#          '▁zahlen': 485,
#          '▁guten': 484,
#          '▁besteht': 483,
#          '▁beste': 483,
#          '▁kosten': 482,
#          '▁tage': 482,
#          '▁woche': 480,
#          '▁sterben': 479,
#          'v': 475,
#          '▁falls': 474,
#          '▁funktionieren': 472,
#          '▁zuvor': 472,
#          '▁zahl': 472,
#          '2': 471,
#          '▁monate': 471,
#          '▁namen': 470,
#          '▁herz': 469,
#          '▁hast': 469,
#          '▁kaufen': 468,
#          'ab': 467,
#          '▁markt': 467,
#          '▁führt': 466,
#          'am': 465,
#          'ch': 464,
#          '▁d': 464,
#          'sen': 463,
#          '▁bereit': 463,
#          '▁stand': 463,
#          '▁lösung': 462,
#          '▁aussehen': 461,
#          '▁neues': 461,
#          '▁prozess': 460,
#          '▁sprach': 460,
#          'ei': 459,
#          '▁größte': 459,
#          '▁ländern': 458,
#          'it': 455,
#          'ale': 455,
#          '▁gefunden': 455,
#          '▁stelle': 454,
#          '▁daraus': 454,
#          '▁wissenschaftler': 453,
#          '▁fliegen': 452,
#          '▁acht': 452,
#          '▁fähigkeit': 452,
#          '▁bewusst': 451,
#          '▁gemeinschaft': 451,
#          '▁möchten': 451,
#          '▁unseres': 449,
#          '▁familien': 447,
#          '▁kraft': 447,
#          '▁beide': 446,
#          '▁bewegung': 446,
#          '▁öl': 446,
#          '▁zellen': 445,
#          '▁draußen': 444,
#          '▁laufen': 444,
#          '▁autos': 443,
#          '▁erschaffen': 441,
#          '▁egal': 440,
#          '▁scheint': 440,
#          '▁krieg': 439,
#          '▁anderer': 439,
#          '▁muster': 439,
#          '▁gelernt': 438,
#          '▁ihres': 438,
#          '▁co': 438,
#          '▁zehn': 437,
#          'ation': 437,
#          '▁modell': 436,
#          '▁stimme': 435,
#          '▁anstatt': 432,
#          '▁nahm': 431,
#          '▁gewesen': 431,
#          '▁schwierig': 431,
#          '▁platz': 430,
#          '▁schritt': 429,
#          '▁gewalt': 429,
#          '▁nimmt': 428,
#          '▁erklären': 428,
#          '▁passieren': 428,
#          '▁gegenüber': 428,
#          '▁sehe': 428,
#          '▁1': 427,
#          '▁technik': 425,
#          '▁re': 425,
#          '▁mache': 424,
#          '▁medien': 424,
#          '▁de': 424,
#          '▁reihe': 423,
#          '▁kleines': 422,
#          '▁eis': 422,
#          '▁anfangen': 422,
#          '▁frei': 422,
#          '▁studenten': 422,
#          '▁wahrheit': 421,
#          '▁beginnt': 421,
#          '▁technologien': 420,
#          '▁fanden': 420,
#          '▁nachdenken': 420,
#          '▁miteinander': 420,
#          '▁verbunden': 419,
#          '▁jemals': 418,
#          '▁richtung': 417,
#          '▁hinein': 417,
#          '▁jahrhundert': 417,
#          '▁geworden': 416,
#          '▁anzahl': 416,
#          '▁teile': 415,
#          '▁alter': 415,
#          '▁klein': 415,
#          '▁verbindung': 415,
#          '▁tatsache': 415,
#          'sp': 413,
#          'me': 412,
#          '▁freund': 412,
#          'ger': 411,
#          '▁leicht': 410,
#          '▁wahl': 409,
#          '▁niemals': 408,
#          '▁labor': 408,
#          '▁morgen': 408,
#          '▁situation': 408,
#          '▁bekommt': 407,
#          '▁sicherheit': 407,
#          '▁bist': 406,
#          '▁information': 406,
#          '▁kleiner': 405,
#          '▁größten': 405,
#          'ne': 405,
#          '▁nacht': 405,
#          '▁schlecht': 404,
#          '▁bildung': 404,
#          '▁tier': 404,
#          'elt': 403,
#          '▁struktur': 403,
#          '▁folgen': 402,
#          '▁glücklich': 402,
#          '▁allein': 402,
#          '▁gebaut': 400,
#          '▁findet': 399,
#          'ben': 399,
#          '▁reise': 399,
#          'ler': 399,
#          '▁foto': 399,
#          '▁schrieb': 398,
#          '▁voll': 396,
#          '▁erfolg': 396,
#          '▁verwendet': 395,
#          '▁stimmt': 395,
#          '▁umgebung': 394,
#          '▁aufgabe': 394,
#          '▁genannt': 394,
#          '▁benutzt': 393,
#          '▁mittel': 393,
#          '▁5': 393,
#          '▁soziale': 393,
#          '▁bereich': 393,
#          '▁sp': 392,
#          '▁vorher': 392,
#          '▁stellte': 392,
#          '▁gezeigt': 392,
#          '▁80': 391,
#          '▁bedeutung': 391,
#          'il': 390,
#          '▁formen': 389,
#          '▁fahren': 389,
#          '▁alten': 388,
#          '▁haupt': 388,
#          '▁richtige': 387,
#          '▁rest': 387,
#          '▁fehler': 386,
#          '▁al': 385,
#          '▁vorstellung': 385,
#          'isches': 385,
#          '▁sofort': 385,
#          '▁rolle': 385,
#          '▁mögen': 385,
#          '▁entfernt': 384,
#          '▁raus': 384,
#          '▁stark': 384,
#          '▁amerika': 383,
#          '▁ziehen': 382,
#          '▁versuche': 382,
#          'iger': 381,
#          '▁preis': 381,
#          '▁erreicht': 381,
#          '▁60': 379,
#          '▁bekannt': 379,
#          '▁veränderung': 379,
#          '▁größe': 379,
#          'ine': 379,
#          '▁team': 379,
#          'ra': 378,
#          '▁setzen': 378,
#          '▁zeige': 378,
#          '▁pflanzen': 378,
#          '▁statt': 376,
#          '▁neben': 376,
#          '▁gingen': 375,
#          '▁rein': 375,
#          '▁arm': 375,
#          'chen': 375,
#          '▁hälfte': 375,
#          '▁forschung': 375,
#          '▁heutzutage': 375,
#          '▁verloren': 374,
#          '▁herausforderung': 374,
#          '▁mitte': 374,
#          '▁jemanden': 374,
#          'liches': 373,
#          '▁lieben': 373,
#          '▁hoffe': 373,
#          '▁offensichtlich': 372,
#          '▁straßen': 372,
#          '▁bekam': 372,
#          '▁links': 371,
#          '▁sonst': 371,
#          '▁gesicht': 370,
#          '▁meinung': 369,
#          '▁ent': 369,
#          '▁papier': 368,
#          '▁absolut': 368,
#          '▁dna': 368,
#          '▁u': 367,
#          '▁wann': 367,
#          '▁weltweit': 367,
#          'end': 367,
#          '▁25': 366,
#          '▁interessiert': 366,
#          '▁straße': 365,
#          '▁einfache': 364,
#          'ber': 364,
#          '▁bücher': 364,
#          '▁brachte': 363,
#          '▁gemeinsam': 363,
#          '▁genommen': 362,
#          '▁länger': 361,
#          '▁o': 361,
#          '▁geboren': 359,
#          '▁komplett': 359,
#          '▁generation': 358,
#          '▁ähnlich': 358,
#          '▁na': 357,
#          '▁fähigkeiten': 357,
#          '▁realität': 357,
#          '▁trotzdem': 357,
#          '▁tod': 357,
#          '▁rechts': 356,
#          '▁geschieht': 355,
#          '▁medizin': 355,
#          '▁krankheit': 355,
#          '▁hinaus': 355,
#          '▁gen': 354,
#          '▁nennt': 353,
#          'ad': 353,
#          '▁online': 353,
#          '▁schneller': 352,
#          '▁gesamte': 352,
#          'ol': 352,
#          ...})

# %%
import pandas as pd

# %%
a, b = cnt.keys(), cnt.values()
data = pd.DataFrame({'len':a, 'freq': b})
total=data['freq'].sum()

# %%
data.head()
# Out:
#      len   freq
# 0  david    204
# 1  gallo      3
# 2      :  10096
# 3   this  38261
# 4     is  49307

# %%
def percent_freq(eq, data):
    print(round(data.loc[data['freq'] < eq]['freq'].count()/data['freq'].count()*100, 2), end='%\n')
    print(round(data.loc[data['freq'] < eq]['freq'].sum()/total*100, 2), end='%\n')

# %%
def percent_len(eq, data):
    print(round(data.loc[data['len'] > eq]['freq'].sum()/total*100, 2), end='%\n')

# %%
data.loc[data['len'] > 0]['freq'].sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data.loc[data['len'] > 0]['freq'].sum()
#
# File c:\Users\Dubinin Daniil\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\Dubinin Daniil\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File c:\Users\Dubinin Daniil\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6121 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\Dubinin Daniil\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File c:\Users\Dubinin Daniil\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# File ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# ## max_len

# %%
from dataset2 import TranslationDataset
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from dataset2 import TranslationDataset
#
# ImportError: cannot import name 'TranslationDataset' from 'dataset2' (c:\Users\Dubinin Daniil\Desktop\bhw2\src\dataset2.py)

# %%
dataset = TranslationDataset(vocab_src, vocab_trg, train_src_filename, train_trg_filename, device='cpu')
# Out:
# 100%|██████████| 195915/195915 [00:07<00:00, 26235.73it/s]

# %%
cnt = dataset.cnt_src

# %%
a, b = cnt.keys(), cnt.values()
data = pd.DataFrame({'word':a, 'freq': b})
total=data['freq'].sum()

# %%
for i in range(64, 31, -4):
    print(i)
    percent_len(i, data)
# Out:
# 64
# 0.47%
# 60
# 0.78%
# 56
# 1.22%
# 52
# 1.83%
# 48
# 2.71%
# 44
# 3.96%
# 40
# 5.68%
# 36
# 8.24%
# 32
# 11.78%

# %%
data_loss = data.loc[data['len'] > 32].sort_values(by='len')

# %%
data_loss['len loss'] = data_loss['len'] -32

# %%
data_loss['word loss'] = data_loss['len loss'] * data['freq']

# %%
data['words'] = data['len'] * data['freq']
total = data['words'].sum()

# %%
data_loss['word loss %'] = data_loss['word loss'] / total * 100

# %%
data_loss
# Out:
#     len  freq  len loss  word loss  word loss %  total word % loss
# 24   33  1956         1     1956.0     0.054488           7.061069
# 42   34  1801         2     3602.0     0.100340           7.006581
# 32   35  1639         3     4917.0     0.136972           6.906241
# 31   36  1528         4     6112.0     0.170261           6.769269
# 27   37  1432         5     7160.0     0.199455           6.599008
# 52   38  1312         6     7872.0     0.219289           6.399553
# 25   39  1213         7     8491.0     0.236532           6.180264
# 45   40  1055         8     8440.0     0.235112           5.943731
# 34   41   949         9     8541.0     0.237925           5.708620
# 49   42   890        10     8900.0     0.247926           5.470694
# 37   43   812        11     8932.0     0.248817           5.222768
# 15   44   735        12     8820.0     0.245697           4.973951
# 29   45   695        13     9035.0     0.251687           4.728254
# 19   46   646        14     9044.0     0.251937           4.476567
# 50   47   569        15     8535.0     0.237758           4.224630
# 44   48   531        16     8496.0     0.236672           3.986872
# 59   49   488        17     8296.0     0.231100           3.750200
# 57   50   424        18     7632.0     0.212603           3.519099
# 8    51   411        19     7809.0     0.217534           3.306496
# 46   52   406        20     8120.0     0.226198           3.088962
# 58   53   333        21     6993.0     0.194803           2.862764
# 61   54   310        22     6820.0     0.189984           2.667961
# 53   55   275        23     6325.0     0.176195           2.477978
# 54   56   274        24     6576.0     0.183187           2.301783
# 51   57   244        25     6100.0     0.169927           2.118597
# 47   58   227        26     5902.0     0.164411           1.948670
# 56   59   221        27     5967.0     0.166222           1.784259
# 66   60   170        28     4760.0     0.132599           1.618037
# 60   61   186        29     5394.0     0.150260           1.485438
# 62   62   145        30     4350.0     0.121177           1.335179
# 70   63   145        31     4495.0     0.125217           1.214001
# 43   64   130        32     4160.0     0.115884           1.088785
# 71   65   104        33     3432.0     0.095605           0.972900
# 55   66   107        34     3638.0     0.101343           0.877296
# 63   67   109        35     3815.0     0.106274           0.775952
# 69   68    89        36     3204.0     0.089253           0.669679
# 73   69    80        37     2960.0     0.082456           0.580425
# 67   70    60        38     2280.0     0.063514           0.497969
# 78   71    76        39     2964.0     0.082568           0.434455
# 48   72    59        40     2360.0     0.065742           0.351888
# 74   73    73        41     2993.0     0.083376           0.286146
# 68   74    39        42     1638.0     0.045630           0.202770
# 72   75    22        43      946.0     0.026353           0.157140
# 76   76    34        44     1496.0     0.041674           0.130788
# 64   77    21        45      945.0     0.026325           0.089114
# 65   78    16        46      736.0     0.020503           0.062789
# 77   79    18        47      846.0     0.023567           0.042287
# 75   80    14        48      672.0     0.018720           0.018720

# %% [markdown]
# ## \<NUM\> token

# %%
import re
pattern_float = r"^-?\+?\d+\.?\,?\d*$"
pattern_has_digit = r"\d"

# %%
cnt = vocab_src.word_counter
words = list(cnt.keys())
floated = list(filter(lambda x: re.match(pattern_float, x), words))
digited = list(filter(lambda x: re.match(pattern_has_digit, x), words))
nums1 = list(filter(lambda x: x.isnumeric(), words))

# %%
set(digited) - set(floated)
# Out:
# {'49th',
#  '1,5m',
#  '90er-jahren',
#  '20-seitige',
#  '2010er',
#  '19.jahrhunderts',
#  '16jährige',
#  '000-stahlwolle',
#  '2-zylinder',
#  '1,500-computer',
#  '1890ern',
#  '60-',
#  '48-jähriger',
#  '30-60',
#  '50-prozentigen',
#  '2-prozentige',
#  '1953er',
#  '10-auf-10-fuß-zelle',
#  '9-jahresperioden',
#  '1930-ern',
#  '30-publikum',
#  '6-',
#  '36-jährigen',
#  '95-prozentige',
#  '14m',
#  '280-quadratmeter-galerie',
#  '240-dollar-mann',
#  '15-jährigen',
#  '2ten',
#  '49-demographie',
#  '40-seitigen',
#  '29-trilliarden-dollar-',
#  '3000-meilen-salats',
#  '100-fache',
#  '80-milliarden-dollar-',
#  '26-jährige',
#  '3-dimensional',
#  '1-treffen',
#  '15jähriger',
#  '16.59h',
#  '102-jährige',
#  '90m',
#  '100-mädchen-projekt',
#  '89-jährigem',
#  '2020ern',
#  '1x2-rechteck',
#  '2000ern',
#  '37-facher',
#  '37-jähriger',
#  '1960ern',
#  '225m',
#  '2002--',
#  '3d-ansicht',
#  '3d-holzkonstruktion',
#  '18-jähriger',
#  '8x8-quadrat',
#  '12-sekunden-flug',
#  '10-nanometer-bereich',
#  '90-prozent-ziel',
#  '25cm',
#  '3d-daten',
#  '13-seitiges',
#  '2d-strichcodes',
#  '84k',
#  '50-basen-stücke',
#  '140g',
#  '70-jährige',
#  '200-fuss-durchmesser',
#  '10-prozentige',
#  '1000-mal',
#  '400-jährige',
#  '2-billiarden-dollar-wirtschaft',
#  '3d-strukturen',
#  '86-jährige',
#  '28-jähriger',
#  '13-jähriger',
#  '65-35',
#  '20cm',
#  '4-4-2',
#  '74.125.226.212',
#  '2-sigma-problem',
#  '18-meter-aufstieg',
#  '150-mal',
#  '3d-brille',
#  '24.000-mal',
#  '25-prozentigen',
#  '14-',
#  '1840ern',
#  '10-meter-gehtest',
#  '10-prozentigen',
#  '60-jährigen',
#  '50-perzentil-amerikaner',
#  '15-24-jährigen',
#  '24-jährigen',
#  '3d-kameras',
#  '500er',
#  '15-stunden-trainings',
#  '3.000-dollar-fluggerät',
#  '21sten',
#  '25mal',
#  '100-dollar-computern',
#  '3d-struktur',
#  '11-gedenkstätte',
#  '8-jährigen',
#  '1,88m',
#  '11-jährige',
#  '20th',
#  '200-jährigen',
#  '3d-mikroskop',
#  '3d-formation',
#  '50-fach',
#  '1990ern',
#  '215-programm',
#  '5x5-quadrat',
#  '360-grad-geräuschortungssystem',
#  '5-sekunden-video',
#  '10mrd',
#  '53-jährige',
#  '0815-gitter',
#  '5-fingertastatur.',
#  '160-pfund-hunde',
#  '100-facher',
#  '65-jährige',
#  '70-ern',
#  '550-hertz-frequenz',
#  '1975er',
#  '20igsten',
#  '450-meter',
#  '60jährige',
#  '3-jährigen',
#  '35-tasten',
#  '90er-jahre',
#  '45-stöckiger',
#  '60-ern',
#  '20-jähriger',
#  '1880er',
#  '360-grad-blick',
#  '40er-jahre-look',
#  '25-größte',
#  '37-jährige',
#  '20-stöckiges',
#  '6-7',
#  '20ern',
#  '70-kilo-pakete',
#  '2.077.000',
#  '95.218.564',
#  '3-wege-kreuzung',
#  '80ern',
#  '40-fache',
#  '12-jähriges',
#  '8-jährige',
#  '5-kanalige',
#  '20-mal',
#  '14jährigen',
#  '30x',
#  '10-12',
#  '20-facher',
#  '5-jährigen',
#  '24h',
#  '12-',
#  '40-tausend',
#  '10-30',
#  '3-d-modell',
#  '1740ern',
#  '70.000-fache',
#  '80-jährige',
#  '40-50',
#  '28.6.1914',
#  '1-million-dollar-frage',
#  '14.tel',
#  '50-jähriges',
#  '11-uhr',
#  '0-5',
#  '200-köpfigen',
#  '17-jähriges',
#  '60.000-dollar-jahresgehalt',
#  '30.000-auto',
#  '90er',
#  '90-grad-ecken',
#  '20.000m',
#  '42ter',
#  '10er',
#  '2,3,4',
#  '42-prozentige',
#  '20-fachen',
#  '9-11',
#  '7.95-box.',
#  '3d-animationen',
#  '100-',
#  '10-fach',
#  '10-dollar-computer',
#  '100km',
#  '6-jährige',
#  '25-dollar',
#  '19ten',
#  '18cm',
#  '1930er',
#  '250-mio.-dollar-bonus',
#  '100.000.000',
#  '15-prozentigen',
#  '80-meter-entfernung',
#  '100-jähriges',
#  '50ste',
#  '72mm-filmmaterial',
#  '10-ergebnisse',
#  '3d-laser-scanningsystem',
#  '1,63m',
#  '46664-stiftung',
#  '2-rad-fahrzeugen',
#  '14-jähriges',
#  '78er',
#  '50x15',
#  '2,10m',
#  '16-faches',
#  '90-jährige',
#  '3d-kamera',
#  '99-prozentige',
#  '3d-rekonstruktion',
#  '4.000m',
#  '16-mal',
#  '2-dollar-am-tag',
#  '10-jähriges',
#  '30-sekunden-überreaktionen',
#  '400-dollar-laptop',
#  '100-dollar-laptop',
#  '15-jähriges',
#  '1.trimesters',
#  '130km',
#  '10-punkt-schrift',
#  '30-tägigen',
#  '11-jähriges',
#  '15jährigen',
#  '900m',
#  '10jährigen',
#  '17-jährige',
#  '30-millionen-dollar-film',
#  '350-dollar',
#  '70ern',
#  '32-jährige',
#  '9-jährigen',
#  '5mal',
#  '24-stunden-phase',
#  '22jährige',
#  '2,44m',
#  '0,6.',
#  '5-jahres-überlebensrate',
#  '40-jähriges',
#  '30-40',
#  '76-jähriger',
#  '15-monatige',
#  '60.000-70.000',
#  '45-grad-winkel',
#  '9jährigen',
#  '1980ern',
#  '3d-bildgebungsananalyse',
#  '12m',
#  '12-seitiges',
#  '42-meter-e-elt',
#  '500-mal',
#  '10er-ring',
#  '4d',
#  '17-stunden-tag',
#  '4-jähriges',
#  '85m',
#  '10-milliarden-dollar-unterbrechung',
#  '45-minütige',
#  '60-stündigen',
#  '8-spur-kassette',
#  '21.-jahrhundert-persönlichkeit',
#  '11-jährigen',
#  '19-jährige',
#  '3d-zeichnen',
#  '3po',
#  '1-schritt-spieler',
#  '22-milliarden-dollar',
#  '100-prozentig',
#  '20-dollar-schein',
#  '3d-version',
#  '29-milliarden-geschäft',
#  '5km',
#  '5-köpfige',
#  '40-jährige',
#  '20-geschossiges',
#  '67m',
#  '25-jährige',
#  '00-14',
#  '120m',
#  '4500m',
#  '10.000fache',
#  '4.klasse',
#  '900-mal',
#  '78rus',
#  '1-',
#  '2,5-meter-marke',
#  '1850ern',
#  '66-jährige',
#  '15-',
#  '1918-grippe',
#  '1-liter-flasche',
#  '50-80',
#  '90-minütige',
#  '45-stöckigen',
#  '90-prozentige',
#  '3x3-quadrat',
#  '400-mal',
#  '45-jährigen',
#  '28-fache',
#  '1000awesomethings.com',
#  '20-',
#  '50ern',
#  '7-sekunden',
#  '100,000-volt',
#  '30-jähriger',
#  '7-jährige',
#  '68.000-dollar',
#  '30-50',
#  '5000-meilen-kabel',
#  '3-mal',
#  '24-stunden-lernumgebung',
#  '70er',
#  '14h',
#  '1000-billionen-',
#  '16mm',
#  '50er',
#  '4-buchstaben-code',
#  '46-jähriger',
#  '10-gramm-phiole',
#  '000stel',
#  '120-volt',
#  '19-',
#  '46664-veranstaltung',
#  '20-20-',
#  '500mal',
#  '11.9.2001',
#  '5,4,3,2,1',
#  '49sten',
#  '8-tamtam',
#  '58er',
#  '19-einhalb',
#  '50-kg-sack',
#  '24-er',
#  '1000m',
#  '20-minuten-umkreis',
#  '2000-mal',
#  '54jähriger',
#  '18-jähriges',
#  '404-fehlerseite',
#  '7-stöckiges',
#  '25-mal',
#  '50.000-mal',
#  '21-prozentigen',
#  '90-grad-winkel.',
#  '200-millionen-dollar-flop',
#  '404-erfahrung',
#  '18-minuten',
#  '450ppm',
#  '270-mal',
#  '16-fach',
#  '3d-darstellung',
#  '1940ern',
#  '60-70',
#  '8-',
#  '000-billionen-mal',
#  '7-achsige',
#  '1947er',
#  '47th',
#  '1994er',
#  '404-seite',
#  '1a',
#  '3d-entwürfe',
#  '900-seiten-buch',
#  '1,95m',
#  '24-stunden-heiligtum',
#  '18-monatigen',
#  '1-wattstunden-zelle',
#  '3g-verbindung',
#  '160km',
#  '56sten',
#  '30-zentimer-kuchen',
#  '9-gängiges',
#  '109fachen',
#  '50kg',
#  '2g',
#  '12-dimensionalen',
#  '1920er',
#  '150-jahr-feier',
#  '20.000-dollar-schuh',
#  '24-stunden-',
#  '9-jährige',
#  '90ern',
#  '4-6',
#  '40-70',
#  '200-millionen-dollar-film',
#  '150-prozentigen',
#  '10.000mal',
#  '42-zoll-plasma-fernseher',
#  '27-seitigen',
#  '6,9km',
#  '3-stündigen',
#  '30-sekunden-interview',
#  '12jährigen',
#  '60zigern',
#  '2d-form',
#  '300er',
#  '15-jähriger',
#  '2x',
#  '60-seitigen',
#  '20er',
#  '5,6-mal',
#  '45-jährige',
#  '2000m',
#  '21.september',
#  '10-problem',
#  '3d',
#  '20-wattstunden-zelle',
#  '3-tages-auftrag',
#  '3d-visualisierung',
#  '40ern',
#  '8-jähriger',
#  '80km',
#  '50-jährige',
#  '5-10',
#  '1830ern',
#  '1-2-3',
#  '400.000-mal.',
#  '1960gern',
#  '100-jährigen',
#  '16-bit',
#  '13jährige',
#  '6-mal',
#  '200.000-jährige',
#  '50-chance',
#  '1970er-jahren',
#  '24-jähriger',
#  '3-d-web',
#  '10-minuten-termin',
#  '150er-marke',
#  '4-bit-symbol',
#  '42km',
#  '100stel',
#  '20-faches',
#  '360-grad-horizont',
#  '10-jährigen',
#  '23-fache',
#  '3d-visualisierungsprogramm',
#  '200mal',
#  '3-jähriger',
#  '2-kilogramm-erdnuss',
#  '3d-viewer',
#  '10-en',
#  '3d-scan',
#  '50-dollarnote',
#  '15-minütige',
#  '100-mal',
#  '7-bildschirme',
#  '2d-bild',
#  '15-stöckiges',
#  '4-steinen',
#  '33-dollar-wein',
#  '100-prozent-monatsbinden-verwendendes',
#  '400-milliarden-dollar',
#  '1970ern',
#  '73m',
#  '30-',
#  '18-einheiten-system',
#  '50zigern',
#  '400-fache',
#  '5-jahres-garantie',
#  '11-zentimter-kuchen',
#  '5cm',
#  '1860er',
#  '80er',
#  '4-schritte-schemas',
#  '39-software',
#  '12-16-18',
#  '14-jähriger',
#  '4.-6',
#  '25m',
#  '2d-konstruktionszeichnung',
#  '747ern',
#  '68er',
#  '12-stunden-flug',
#  '5-grundpfeiler',
#  '75-jährige',
#  '64-',
#  '79er-revolution',
#  '60cm',
#  '50-prozent',
#  '5c',
#  '14cm',
#  '28-dollar',
#  '6db',
#  '60-minütigen',
#  '7-11',
#  '45-grad-steigung',
#  '360-grad',
#  '1-ratio',
#  '3d-skulptur',
#  '90-er',
#  '8-minütiger',
#  '36-stunden-schicht',
#  '3dz',
#  '30-jährige',
#  '3d-beschleunigungssensor',
#  '4th',
#  '1300m',
#  '8-stellen-grenze',
#  '30jährigen',
#  '4jährige',
#  '30-sekündige',
#  '30-tägige',
#  '259.105.570',
#  '2009-ausgabe',
#  '60er',
#  '1950er',
#  '3d-verständnis',
#  '50km',
#  '24-stunden-wettbewerb',
#  '4-mal',
#  '7-',
#  '5-',
#  '300m',
#  '2-tonnen-maschiene',
#  '46jährige',
#  '2-stunden-rennens',
#  '300-millionen-dollar-methode',
#  '1850er',
#  '18-jährige',
#  '000-dollar-hawaii-urlaubspaket',
#  '3d-gedruckt',
#  '2,5-fache',
#  '2008-09',
#  '90-grad-winkel',
#  '17-jahres-vertrag',
#  '20m',
#  '1-800-got-junk',
#  '20-jährige',
#  '577r-genotyp',
#  '18-jährigen',
#  '3d-printing',
#  '4-',
#  '16ten',
#  '1-mm-radius',
#  '21-jährige',
#  '90ps',
#  '28-jährigen',
#  '60-er',
#  '1950gern',
#  '3-milliarden-dollar-hadronenbeschleuniger',
#  '5-millionen-dollar-kameras',
#  '16tes-jahrhundert-technologie',
#  '80-',
#  '3-sterne',
#  '1000-fache',
#  '30-geschossigen',
#  '13.56h',
#  '42nd',
#  '5-punkte-rahmen',
#  '140-zeichen-limit',
#  '18-monats-scan',
#  '700-euro-kamera',
#  '50.000-kredit',
#  '70-meter-standard-distanz',
#  '40-personen-unternehmen',
#  '3,5m',
#  '1-gigawatt-kohlekraftwerk',
#  '12-jährigen',
#  '1930er-jahre',
#  '20-minütige',
#  '24-stündige',
#  '3d-software',
#  '72kg',
#  '14th',
#  '19-jähriger',
#  '256-leitungs-eeg',
#  '6-jähriger',
#  '10.30h',
#  '50m',
#  '30km-radius',
#  '76er',
#  '80-jährigen',
#  '3d-raum',
#  '1x1',
#  '15-megawatt-flügel',
#  '12-jährige',
#  '4-takt-wechsel',
#  '3d-spiele',
#  '600m',
#  '1000-fach',
#  '62-jähriger',
#  '2fachen',
#  '3-drehung',
#  '000-faches',
#  '30,5m',
#  '2000er',
#  '401-pensionsplan',
#  '10-jährige',
#  '14er',
#  '3d-organ',
#  '42-kilometer-rennen',
#  '3w-modell',
#  '46jähriger',
#  '22-jährige',
#  '1930ern',
#  '4-takt',
#  '21-jähriger',
#  '16-jährige',
#  '3-dimensionale',
#  '1870er',
#  '3d-graphiken',
#  '7te',
#  '90km',
#  '1970er',
#  '100.000-sportwagen',
#  '10.000-jahr-uhr',
#  '1870ern',
#  '800m',
#  '24h-betrieb',
#  '90ziger',
#  '30-35',
#  '20-dollar-scheine',
#  '2-jähriges',
#  '1920ern',
#  '5ter',
#  '50mal',
#  '75-25',
#  '100fache',
#  '6-liter-motor',
#  '3d-labyrinth',
#  '150-jährigen',
#  '46-jährigen',
#  '2x2-quadrat',
#  '200-jahr-geschichte',
#  '160-175',
#  '3d-kino',
#  '6-beinigen',
#  '7-stündige',
#  '17-jähriger',
#  '100-watt-glühbirne',
#  '15-jährige',
#  '5th',
#  '30m',
#  '30-jahre-perspektive',
#  '20jährigen',
#  '18-minütigen',
#  '70er-jahren',
#  '75kg',
#  '1750er',
#  '4d-printing',
#  '74-fachen',
#  '50-prozentige',
#  '50-ern',
#  '3d-druck',
#  '33-dollar-weinflasche',
#  '1-markt',
#  '500-kredit',
#  '12-stöckiges',
#  '30-jahre-zyklus',
#  '50-50',
#  '1,86m',
#  '100-jährige-des-monats',
#  '100-meter-entfernung',
#  '20-prozentigen',
#  '2d',
#  '16stöckiges',
#  '3d-form',
#  '10.000-seiten',
#  '80-prozentige',
#  '34-jähriger',
#  '13-jährigen',
#  '40-45',
#  '1960er',
#  '20m-katamaran',
#  '33-prozentigen',
#  '30cm',
#  '120th',
#  '6-3-2',
#  '4m',
#  '47-jähriger',
#  '7-minütiges',
#  '106-mal',
#  '80ger',
#  '100er',
#  '1.000-dollar',
#  '100-jährige',
#  '35-watt-lasers',
#  '25-megawatt',
#  '30-jahres-zyklen',
#  '20.000-dollar-anlagen',
#  '16-jähriger',
#  '3.000-quadratfuß-drachen',
#  '1,5km',
#  '4w-modell',
#  '30-moscheen-reise',
#  '700.000-',
#  '2001-2002',
#  '22-jährigen',
#  '17-silben-ding',
#  '70-jährigen',
#  '18h',
#  '24-stunden-wasserversorgung',
#  '47er',
#  '1.0-fehler',
#  '5-jähriger',
#  '38-jähriger',
#  '10-stellen-rechner',
#  '1-800-genocide',
#  '12h',
#  '10mal',
#  '800-köpfigen',
#  '300-prozentige',
#  '30er',
#  '1.000-jährige',
#  '30-jährigen',
#  '400km-bereich',
#  '1000-gallonen-einheiten',
#  '95prozentige',
#  '200-dollar-pro-barrel-paket',
#  '20-30',
#  '20-dimensionale',
#  '3d-heber',
#  '300km',
#  '450-watt-turbine',
#  '19jährige',
#  '400ppm',
#  '23x8',
#  '10-sekunden-version',
#  '200-liter-ölfass',
#  '1-million-menschen-',
#  '1880ern',
#  '13-minütigen',
#  '90-zigern',
#  '50-jähriger',
#  '45-60',
#  '0,1-prozentige',
#  '78-einhalb',
#  '30-mal',
#  '15h',
#  '24-stündigen',
#  '700er',
#  '4-fache',
#  '8.01h',
#  '390ppm',
#  '3m',
#  '1m',
#  '6-millionen-erbe',
#  '25-percentil-amerikanerin',
#  '32-köpfiges',
#  '80-jähriger',
#  '600-mal',
#  '28-jährige',
#  '5-minütige',
#  '1-jährigen',
#  '9-1-1',
#  '12er',
#  '15.april',
#  '78-jähriger',
#  '7-mal',
#  '60ern',
#  '3d-simulator-engine',
#  '16-millimeter',
#  '40-kilometer-marsches',
#  '17-jährigen',
#  '3d-animationssoftware',
#  '5kg',
#  '20-regel',
#  '25-jährigen',
#  '40-euro-kamera',
#  '26-jährigen',
#  '23-jährige',
#  '99,9997-prozentigen',
#  '55.000-dollar-riese',
#  '30project.org',
#  '24-stunden',
#  '11-cm-kuchen',
#  '3d-modelle',
#  '42-stöckiges',
#  '300-',
#  '3d-spiel',
#  '24-jährige',
#  '90-m-tauchgang',
#  '1960er-jahren',
#  '727er',
#  '50-100',
#  '2nd',
#  '20-fach',
#  '404-gefühl',
#  '1.600-fache',
#  '4g-netzwerk',
#  '14-kanal',
#  '3-10',
#  '18-',
#  '10-stunden-tag',
#  '2g-telefonen',
#  '2mal',
#  '6-wöchigen',
#  '16-jährigen',
#  '3-d',
#  '8x10',
#  '1,55m',
#  '1-minuten-frequenz',
#  '5x',
#  '5-mal',
#  '10-stockwerke',
#  '14jähriges',
#  '16-facher',
#  '0-8-15-protein',
#  '2-3',
#  '59-jähriger',
#  '0800-nummer',
#  '18jähriger',
#  '30-jahre',
#  '36-stöckiges',
#  '10-cent',
#  '30minütigen',
#  '75-',
#  '90-prozentiger',
#  '7.kavallerie',
#  '65-jährigen',
#  '160kg',
#  '3d-datenbank',
#  '1900ern',
#  '11-zoll-durchmesser',
#  '15-prozent-regel',
#  '60-monatskarten',
#  '29-jährigen',
#  '12-stufen',
#  '30-millimeter',
#  '800-meter-entfernung',
#  '40er',
#  '600-millionenfache',
#  '10tausend',
#  '44-jährigen',
#  '1923er',
#  '80stes',
#  '1-800-fight-bribes',
#  '5-milliarden-dollar-industrie',
#  '25-30',
#  '100-acre',
#  '15-monatigen',
#  '50-overs-cricket',
#  '3000m',
#  '24.000m',
#  '7.770.000',
#  '30.000-fach',
#  '22,5kg',
#  '30-minuten-recherche',
#  '40-60',
#  '10-',
#  '105-jährigen',
#  '50er-jahre-sitcom-version',
#  '120-mal',
#  '26.april',
#  '24-stunden-berichterstattung',
#  '1963er',
#  '6j6',
#  '12-14',
#  '10m',
#  '3d-drucken',
#  '6-12',
#  '19te',
#  '2-personen-badewanne',
#  '1900er.',
#  '1500ern',
#  '12-sekunden-schritte',
#  '3g-funkverbindung',
#  '2001er',
#  '1-liter-flaschen',
#  '14-stündigen',
#  '65jährigen',
#  '450g',
#  '1990er',
#  '15-monate',
#  '6-meter-wellen',
#  '4.000m-verfolgung',
#  '463-millionen-dollar-geschäft',
#  '2001-02',
#  '100-prozentige',
#  '7,6cm',
#  '70-er',
#  '3-tages-rhythmus',
#  '4-7',
#  '3d-blase',
#  '1800ern',
#  '16-zentimeter',
#  '28mm-objektiv',
#  '20-buchstaben-code',
#  '1000-core-supercomputer',
#  '3-4',
#  '2-sekunden',
#  '1x1-quadrat',
#  '20-millionen-stadt',
#  '36-jährige',
#  '4-jährige',
#  '141st',
#  '11-jähriger',
#  '5-jahresplan',
#  '3000-fach',
#  '2000-basen-löschung',
#  '100m',
#  '4.tag',
#  '4-wege-stoppschilder',
#  '35-stundenwoche',
#  '1980iger',
#  '1980er',
#  '12-volt-steckdose',
#  '200-millionen-quadratmeter',
#  '19-jährigen',
#  '5000-byte-universum',
#  '20-dollar-noten',
#  '3d-drucker',
#  '15j',
#  '80-mal',
#  '4-monatige',
#  '30-sekunden-intro',
#  '16mm-filmkameras',
#  '10h',
#  '3d-druckverfahren',
#  '270m',
#  '60-80',
#  '1-millionen-einwohner-stadt',
#  '50-20',
#  '90-grad-wende',
#  '100-punkte-skala',
#  '000-mal',
#  '100-und-mehr',
#  '75jährige',
#  '30-jahre-periode',
#  '3t',
#  '14-jährigen',
#  '8-unzen',
#  '100-prozent-ziele',
#  '27jährigen',
#  '6mal',
#  '3d-laserscanning-systeme',
#  '30ern',
#  '5-cent-gebühr',
#  '7er-schritten',
#  '4chan',
#  '18-monatiges',
#  '2-jähriger',
#  '1800er',
#  '2020er',
#  '32-fache',
#  '1780ern',
#  '3d-karte',
#  '20-overs-spiel',
#  '3g',
#  '5-billionen-dollar-preises',
#  '6-jährigen',
#  '21.jahrhunderts',
#  '10-cent-stücks',
#  '1,2l',
#  '1910er',
#  '1950ern',
#  '46cm',
#  '500fache',
#  '7-jährigen',
#  '200-jahr-plans',
#  '30-tage-dosis',
#  '11.39h',
#  '12-jähriger',
#  '4-kilowattstunden-zelle',
#  '8-beinigen',
#  '10-cm-nadel',
#  '14-fach',
#  '1991-92',
#  '6g',
#  '4shbab',
#  '17-18',
#  '50-mal',
#  '800km',
#  '200-jährige',
#  '5-jährige',
#  '2030ern',
#  '350ppm',
#  '7-up',
#  '87-jährigen',
#  '401-plan',
#  '15-sekunden-lange',
#  '3d-messpunkte',
#  '20-dollarschein',
#  '100-dollar-computer',
#  '800-pfund-gorilla',
#  '500-seiten',
#  '150-jährige',
#  '3d-bilder',
#  '1-us-dollar-schein',
#  '10-20',
#  '40.000-dollar-limousine',
#  '30-jahres-ding',
#  '27-jährige',
#  '10-fache',
#  '83-jährige',
#  '20-jährigen',
#  '1650er',
#  '70zigern',
#  '13-jährige',
#  '23andme',
#  '3-d-modells',
#  ...}

# %%
cnt = vocab_src.word_counter
words = list(cnt.keys())
nums = list(filter(lambda x: x.isnumeric(), words))
